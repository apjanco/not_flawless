# %%
# !export PORTKEY_API_KEY=Dwe0n6LaEr0xSe7sreXmSXP3fcJo

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd()))
from evaluators import gemini_eval

# %%
metrics = gemini_eval.evaluate()
print("\nFinal metrics:")
for k, v in metrics.items():
    print(f"  {k}: {v}")
# Out:
# [2026-04-25 06:31:31] [gemini-portkey] Starting Gemini evaluation via Portkey
# [2026-04-25 06:31:43] [gemini-portkey] Loaded 10373 images from full IAM dataset
# [2026-04-25 06:31:43] [gemini-portkey] Loaded checkpoint: 10372 samples already processed
# [2026-04-25 06:31:43] [gemini-portkey] Progress: 10372/10373 samples completed
# [2026-04-25 06:31:43] [gemini-portkey] Will process 1 remaining samples
# gemini-portkey: 100%|██████████| 1/1 [00:11<00:00, 11.72s/img]
# [2026-04-25 06:31:55] [gemini-portkey] Checkpoint saved: 10373 samples processed
# [2026-04-25 06:31:55] [gemini-portkey] Checkpoint saved: 10373 samples processed
# [2026-04-25 06:31:55] [gemini-portkey] Saved 10458 results to gemini-portkey_results.jsonl
# [2026-04-25 06:31:55] [gemini-portkey] Evaluation complete. Progress: 10373/10373
#
# Final metrics:
#   num_samples: 10373
#   num_successful: 10288
#   num_errors: 85
#   mean_cer: 6.9651573673924965
#   median_cer: 2.5641025975346565
#   min_cer: 0.0
#   max_cer: 1466.6666984558105
#   mean_wer: 28.491953625064063
#   median_wer: 25.0
#   min_wer: 0.0
#   max_wer: 3000.0
#   mean_inference_time: 9.717015702136283
#   total_inference_time: 100794.60387825966
#   checkpoint_info: {'total_samples': 10373, 'processed_samples': 10373, 'remaining_samples': 0, 'is_complete': True}
